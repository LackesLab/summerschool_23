# %%
import torch
torch.manual_seed(22)

# %% [markdown]
# ### Aufgabe 1
# #### Schritt 1 :Daten lesen
# Lese das Datenset ein. Erstelle eine Liste mit einzigartigen Zeichen aus dem Datenset. (Datenset liegt in tsa04)

# %% [markdown]
# #### Schritt 2: Encode und Decode
# Erstelle 2 Funktionen, Encode und Decode, die die Konvertierung von String zu einem Int übernhemen und umgekehrt. Der Einfachheit halber stzen wir in dieser Übung auf ein Character Based Encoding

# %%
print(encode("generative ai"))
print(decode(encode("generative ai")))

# %% [markdown]
# #### Schritt 3
# Nutze die Funktion Encode um das Datenset zu encoden.

# %% [markdown]
# #### Schritt 4
# Implementiere einen Expanding-Window Split für das Datenset

# %% [markdown]
# ## Self-Attention

# %% [markdown]
# Wir haben heute im Rahmen der Vorlesung die einzelnen Schritte im Selt-Attention Layer Forward Step besprochen. In dieser Übung soll die die Implementierung des Forward Step noch einmal klar verdeutlichen wie der Vorgang von statten geht.
#
# Nutze für die einzelnen Schritte die Visualisierungen der Folien

# %% [markdown]
# ### Schritt 1: Input initialiseren
# Initialiseren die Eingabevariable. Für dieses Beispiel wollen wir 3 Tokens verarbeiten, die jeweils als Embedding der Länge 4 dargestellt sind.

# %% [markdown]
# ### Schritt 2: Initialisiere die Gewichte
# Für dieses Beispiel haben K, V, Q 5 Gewichte Werte

# %% [markdown]
# ### Schritt 3: Berechne die Ergebnisse für Key, Value und Query mit deinen Eingabevariablen

# %% [markdown]
# ### Schritt 4 Berechne die Attention Scores mithilfe der Query eines jeden Inputs

# %% [markdown]
# ### Schritt 5: Berchne den Softmax über die Query Scores

# %% [markdown]
# ### Schritt 6: Berechne den finale Self-Attention Score

# %% [markdown]
# ## Weiterführendes
# Video: https://www.youtube.com/watch?v=kCc8FmEb1nY
#
# Andrej Karpathy zeigt in seinem Video: Lets build GPT die Funktionsweise von GPT, geht im speziellen auf mathematische Tricks in der Berechnung und die Integration in ein bestehendes Modell ein.
#
# Nimm dir zu Hause noch einmal die Zeit, und arbeite das Video durch. Es hilft, die Verbindung der mathematischen Vektormultiplikationen sowie dem Vorhersagenden Modell besser zu verstehen.

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('kCc8FmEb1nY')
